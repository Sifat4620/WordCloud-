# %%
# !pip install wordcloud matplotlib
# Out:
# Collecting wordcloud
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/ca/4a/49ceaa60945f2e0077c25117dd99c7e6efdea9cc970787d0637a36e39014/wordcloud-1.9.2-cp39-cp39-win_amd64.whl.metadata
#   Downloading wordcloud-1.9.2-cp39-cp39-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: matplotlib in c:\users\mdsif\anaconda3\lib\site-packages (3.5.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\mdsif\anaconda3\lib\site-packages (from wordcloud) (1.26.0)
# Requirement already satisfied: pillow in c:\users\mdsif\anaconda3\lib\site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mdsif\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mdsif\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mdsif\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\mdsif\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mdsif\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mdsif\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\mdsif\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading wordcloud-1.9.2-cp39-cp39-win_amd64.whl (153 kB)
#    -------------------------------------- 153.3/153.3 kB 611.4 kB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.2
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
text = "This is a word cloud example. It shows the most frequent words in a text."

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
